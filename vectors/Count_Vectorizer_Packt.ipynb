# %%
# imports

# %%
nltk.download("wordnet")
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nltk.download("wordnet")
#       2 nltk.download('punkt')
#       3 nltk.download('averaged_perceptron_tagger')
#
# NameError: name 'nltk' is not defined

# %%
# https://www.kaggle.com/shivamkushwaha/bbc-full-text-document-classification
# !wget -nc https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Out:
# --2024-02-26 01:16:49--  https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3030::ac43:d5a6, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5085081 (4.8M) [text/csv]
# Saving to: ‘bbc_text_cls.csv’
#
# bbc_text_cls.csv    100%[===================>]   4.85M  5.31MB/s    in 0.9s
#
# 2024-02-26 01:16:51 (5.31 MB/s) - ‘bbc_text_cls.csv’ saved [5085081/5085081]

# %%
# What is the vector dimensionality in each case?
# Compare them and consider why they are larger / smaller

# %% [markdown]
# ![](https://deeplearningcourses.com/notebooks_v3_pxl?sc=lEc35PCn7ki84DnblrywGQ&n=Count+Vectorizer)
